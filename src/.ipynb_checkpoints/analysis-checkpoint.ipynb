# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pandas as pd
# %matplotlib inline

# %%
df_mushrooms = pd.read_csv('../data/mushroom_data.csv')

# %%
df_mushrooms.shape
# Out:
# (8124, 23)

# %%
df_mushrooms[2:10]
# Out:
#   class cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
# ...
